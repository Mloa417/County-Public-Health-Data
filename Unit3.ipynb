# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Overview
# - Walkthrough tutorial on how to gather a subset of the data from County Public Health Data
# - importing pandas and numpty
# - data frame creation
# - filtering data frame
# - Finished product will focus on uninsured, unemployed, and food security based on region
#
# ### Importing Pandas
# - You will begin by importing pandas using the following command.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Creating Data Frame
# - In order to create a data frame, use the following command.
#     - "df=pd.read_csv and insert file as ('')

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CountyHealthData_2014-2015 (1).csv')

# %%
df.dtypes
# Out:
# State                                object
# Region                               object
# Division                             object
# County                               object
# FIPS                                  int64
#                                      ...
# Other primary care providers        float64
# Median household income               int64
# Children eligible for free lunch    float64
# Homicide rate                       float64
# Inadequate social support           float64
# Length: 64, dtype: object

# %% [markdown]
# ### Filtering Data
# - We will begin with filtering out the regions and then the specific categories which will include "unemployment", "uninsured", and "food security"
#
# #### Steps
# - Begin by using the following command df[[ ]] and you may insert the following terms (use parentheses and commas to separate the terms): "Region", "Year", "Unemployment", "Uninsured", "Food insecurity"

# %%
df[["Region", "Year", "Unemployment", "Uninsured", "Food insecurity"]]
# Out:
#      Region      Year  Unemployment  Uninsured  Food insecurity
# 0      West  1/1/2014         0.091      0.355            0.170
# 1      West  1/1/2015         0.088      0.293            0.173
# 2      West  1/1/2014         0.054      0.183            0.126
# 3      West  1/1/2015         0.050      0.198            0.125
# 4      West  1/1/2014         0.152      0.287            0.199
# ...     ...       ...           ...        ...              ...
# 6104   West  1/1/2015         0.047      0.158            0.119
# 6105   West  1/1/2014         0.054      0.183            0.117
# 6106   West  1/1/2015         0.050      0.188            0.125
# 6107   West  1/1/2014         0.051      0.169            0.116
# 6108   West  1/1/2015         0.043      0.162            0.122
#
# [6109 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %% [markdown]
# - Now let us isolate the following data set
#     - We will do this by looking at specifically the Year 2015

# %%
df["Year"]== 1/1/2015
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6104    False
# 6105    False
# 6106    False
# 6107    False
# 6108    False
# Name: Year, Length: 6109, dtype: bool

# %%
df[["Region", "Unemployment", "Uninsured", "Food insecurity"]][df["Year"]== 1/1/2015]
# Out:
# Empty DataFrame
# Columns: [Region, Unemployment, Uninsured, Food insecurity]
# Index: []
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_23.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  counted = (series['index']
                .value_counts()
              .reset_index(name='counts')
              .rename({'index': 'index'}, axis=1)
              .sort_values('index', ascending=True))
  xs = counted['index']
  ys = counted['counts']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_23.sort_values('index', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('index')
_ = plt.ylabel('count()')
